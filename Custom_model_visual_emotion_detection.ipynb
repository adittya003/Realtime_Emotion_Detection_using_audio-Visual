# %%
import numpy as np
import pandas as pd

# %%
# with ZipFile(path+'archive (3).zip','r') as ZipObj:
#  ZipObj.extractall(path+'dataset')

# %%
path='/kaggle/input/emotion/'

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from PIL import Image
from sklearn.model_selection import train_test_split

# %%
angry_train = os.listdir(path+'/train/angry')
disgusted_train=os.listdir(path+'/train/disgusted')
fearful_train=os.listdir(path+'/train/fearful')
happy_train=os.listdir(path+'/train/happy')
neutral_train=os.listdir(path+'/train/neutral')
sad_train=os.listdir(path+'/train/sad')
suprised_train=os.listdir(path+'/train/surprised')

# %%
print(disgusted_train[-5:])
# Out:
# ['im92.png', 'im430.png', 'im153.png', 'im326.png', 'im391.png']

# %%
angry=path+'/train/angry/'
disgusted=path+'/train/disgusted/'
fearful=path+'/train/fearful/'
happy=path+'/train/happy/'
neutral=path+'/train/neutral/'
sad=path+'/train/sad/'
suprised=path+'/train/surprised/'

# %%
img = mpimg.imread(angry+'im953.png')
imgplot = plt.imshow(img)
plt.show()

# %%
img2=mpimg.imread(disgusted+'/im96.png')
img2plot=plt.imshow(img2)
plt.show()

# %% [markdown]
# #**Train** **DATASETS**

# %%
print(len(angry_train),
len(disgusted_train),
len(fearful_train),
len(happy_train),
len(neutral_train),
len(sad_train),
len(suprised_train))
# Out:
# 3995 436 4097 7215 4965 4830 3171

# %%
data=[]

# %%
import random

# %%
for i in angry_train:
  image=Image.open(angry+i)
  image = image.resize((32,32))
  image = np.array(image)
  data.append(image)

# %%
for i in range(9):
    for i in disgusted_train:
      image=Image.open(disgusted+i)
      image = image.resize((32,32))
      image = np.array(image)
      data.append(image)

# %%
for i in fearful_train:
  image=Image.open(fearful+i)
  image = image.resize((32,32))
  image = np.array(image)
  data.append(image)

# %%
for i in happy_train:
  image=Image.open(happy+i)
  image = image.resize((32,32))
  image = np.array(image)
  data.append(image)

# %%
for i in sample_happy:
  image=Image.open(neutral+i)
  image = image.resize((32,32))
  image = np.array(image)
  data.append(image)

# %%
for i in sad_train:
  image=Image.open(sad+i)
  image = image.resize((32,32))
  image = np.array(image)
  data.append(image)

# %%
for i in suprised_train:
  image=Image.open(suprised+i)
  image = image.resize((32,32))
  image = np.array(image)
  data.append(image)

# %%
len(data)
# Out:
# 27352

# %%
data[0]
# Out:
# array([[255, 255, 254, ...,   6,   7,  11],
#        [255, 255, 254, ...,   6,   7,  13],
#        [255, 255, 255, ...,   0,   9,   9],
#        ...,
#        [210, 195, 204, ...,  19,  43,  12],
#        [216, 249, 255, ...,  50,  13,   5],
#        [255, 255, 255, ..., 138,  88,   0]], dtype=uint8)

# %%
data[3000].shape
# Out:
# (32, 32)

# %%
angry_var=[0]*3995
disgusted_var=[1]*3924
fearful_var=[2]*4097
happy_var=[3]*7215
neutral_var=[4]*4965
sad_var=[5]*4830
suprised_var=[6]*3171
y=[]
y.extend(angry_var)
y.extend(disgusted_var)
y.extend(fearful_var)
y.extend(happy_var)
y.extend(neutral_var)
y.extend(sad_var)
y.extend(suprised_var)

# %%
len(data)
# Out:
# 27352

# %%
len(y)
# Out:
# 32197

# %%
type(data[0])
# Out:
# numpy.ndarray

# %%
from tensorflow.keras.utils import to_categorical

# %%
y_train_encoded = to_categorical(y, num_classes=7)

# %%
X_train = np.array(data)
Y_train = np.array(y_train_encoded)

# %% [markdown]
# #**Test DATASETS**

# %%
angry_test = os.listdir(path+'/test/angry/')
disgusted_test=os.listdir(path+'/test/disgusted/')
fearful_test=os.listdir(path+'/test/fearful/')
happy_test=os.listdir(path+'/test/happy/')
neutral_test=os.listdir(path+'/test/neutral/')
sad_test=os.listdir(path+'/test/sad/')
suprised_test=os.listdir(path+'/test/surprised/')

# %%
print(len(angry_test),
len(disgusted_test),
len(fearful_test),
len(happy_test),
len(neutral_test),
len(sad_test),
len(suprised_test))
# Out:
# 958 111 1024 1774 1233 1247 831

# %%
data_test=[]

# %%
angry=path+'/test/angry/'
disgusted=path+'/test/disgusted/'
fearful=path+'/test/fearful/'
happy=path+'/test/happy/'
neutral=path+'/test/neutral/'
sad=path+'/test/sad/'
suprised=path+'/test/surprised/'

# %%
for i in angry_test:
  image=Image.open(angry+i)
  image = image.resize((32,32))
  image = np.array(image)
  data_test.append(image)

# %%
for i in disgusted_test:
  image=Image.open(disgusted+i)
  image = image.resize((32,32))
  image = np.array(image)
  data_test.append(image)

# %%
for i in fearful_test:
  image=Image.open(fearful+i)
  image = image.resize((32,32))
  image = np.array(image)
  data_test.append(image)

# %%
for i in happy_test:
  image=Image.open(happy+i)
  image = image.resize((32,32))
  image = np.array(image)
  data_test.append(image)

# %%
for i in neutral_test:
  image=Image.open(neutral+i)
  image = image.resize((32,32))
  image = np.array(image)
  data_test.append(image)

# %%
for i in sad_test:
  image=Image.open(sad+i)
  image = image.resize((32,32))
  image = np.array(image)
  data_test.append(image)

# %%
for i in suprised_test:
  image=Image.open(suprised+i)
  image = image.resize((32,32))
  image = np.array(image)
  data_test.append(image)

# %%
len(data_test)
# Out:
# 7178

# %%
angry_var2=[0]*958
disgusted_var2=[1]*111
fearful_var2=[2]*1024
happy_var2=[3]*1774
neutral_var2=[4]*1233
sad_var2=[5]*1247
suprised_var2=[6]*831
y_test=[]
y_test.extend(angry_var2)
y_test.extend(disgusted_var2)
y_test.extend(fearful_var2)
y_test.extend(happy_var2)
y_test.extend(neutral_var2)
y_test.extend(sad_var2)
y_test.extend(suprised_var2)

# %%
y_test_encoded = to_categorical(y_test, num_classes=7)

# %%
y_test_encoded.shape
# Out:
# (7178, 7)

# %%
len(y_test_encoded)
# Out:
# 7178

# %%
data_test[100].shape
# Out:
# (32, 32)

# %%
type(data[100])
# Out:
# numpy.ndarray

# %%
X_test= np.array(data_test)
Y_test = np.array(y_test_encoded)

# %%
x_test_scaled=X_test/255

# %%
x_train_scaled=X_train/255

# %%
x_train_scaled
# Out:
# array([[[1.        , 1.        , 0.99607843, ..., 0.02352941,
#          0.02745098, 0.04313725],
#         [1.        , 1.        , 0.99607843, ..., 0.02352941,
#          0.02745098, 0.05098039],
#         [1.        , 1.        , 1.        , ..., 0.        ,
#          0.03529412, 0.03529412],
#         ...,
#         [0.82352941, 0.76470588, 0.8       , ..., 0.0745098 ,
#          0.16862745, 0.04705882],
#         [0.84705882, 0.97647059, 1.        , ..., 0.19607843,
#          0.05098039, 0.01960784],
#         [1.        , 1.        , 1.        , ..., 0.54117647,
#          0.34509804, 0.        ]],
#
#        [[1.        , 1.        , 0.78823529, ..., 1.        ,
#          1.        , 1.        ],
#         [1.        , 0.99215686, 0.69411765, ..., 1.        ,
#          1.        , 1.        ],
#         [1.        , 0.98823529, 0.6745098 , ..., 1.        ,
#          1.        , 1.        ],
#         ...,
#         [1.        , 0.95686275, 0.97254902, ..., 1.        ,
# ...

# %% [markdown]
# #**CREATING** **CNN**

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers as ly

# %%
num_classes=7
model=keras.Sequential()

# %%
model.add(keras.layers.Conv2D(128, kernel_size=(4, 4), strides=(1, 1), padding='same', activation='relu', input_shape=(32, 32, 1)))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

# Change kernel size from (2, 2) to (4, 4)
model.add(keras.layers.Conv2D(32, kernel_size=(4, 4), strides=(2, 2), padding='same', activation='relu'))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

# Change kernel size from (2, 2) to (4, 4)
model.add(keras.layers.Conv2D(32, kernel_size=(4, 4), strides=(1, 1), padding='same', activation='relu'))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(num_classes, activation='softmax'))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_21 (Conv2D)              │ (None, 32, 32, 128)    │         2,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 8, 8, 32)       │        65,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 4, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 4, 4, 32)       │        16,416 │
# ...

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])

# %%
history = model.fit(x_train_scaled, Y_train, validation_split=0.25, epochs=10)
# Out:
# Epoch 1/10
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - acc: 0.3254 - loss: 1.6071 - val_acc: 0.0000e+00 - val_loss: 6.3957
# Epoch 2/10
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - acc: 0.3522 - loss: 1.4957 - val_acc: 0.0000e+00 - val_loss: 5.3615
# Epoch 3/10
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - acc: 0.4557 - loss: 1.3193 - val_acc: 0.0000e+00 - val_loss: 7.0479
# Epoch 4/10
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - acc: 0.5402 - loss: 1.1618 - val_acc: 0.0000e+00 - val_loss: 7.4393
# Epoch 5/10
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - acc: 0.5911 - loss: 1.0295 - val_acc: 0.0000e+00 - val_loss: 8.9404
# Epoch 6/10
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - acc: 0.6248 - loss: 0.9206 - val_acc: 0.0000e+00 - val_loss: 10.2849
# Epoch 7/10
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - acc: 0.6416 - loss: 0.8773 - val_acc: 0.0000e+00 - val_loss: 11.3124
# Epoch 8/10
# ...

# %%
loss, accuracy = model.evaluate(x_test_scaled, Y_test)
print('Test Accuracy =', accuracy)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.4367 - loss: 2.2059
# Test Accuracy = 0.330872118473053

# %%
model2 = tf.keras.models.Sequential([
    # 1st conv
  tf.keras.layers.Conv2D(96, (11,11),strides=(4,4), activation='relu', input_shape=(32, 32, 1)),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(2, strides=(2,2)),
    # 2nd conv
  tf.keras.layers.Conv2D(256, (11,11),strides=(1,1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
     # 3rd conv
  tf.keras.layers.Conv2D(384, (3,3),strides=(1,1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
    # 4th conv
  tf.keras.layers.Conv2D(384, (3,3),strides=(1,1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
    # 5th Conv
  tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(2, strides=(2, 2)),
  # To Flatten layer
  tf.keras.layers.Flatten(),
  # To FC layer 1
  tf.keras.layers.Dense(4096, activation='relu'),
    # add dropout 0.5 ==> tf.keras.layers.Dropout(0.5),
  #To FC layer 2
  tf.keras.layers.Dense(4096, activation='relu'),
    # add dropout 0.5 ==> tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(num_classes, activation='softmax')
])

# %%
model2.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_24 (Conv2D)              │ (None, 6, 6, 96)       │        11,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 6, 6, 96)       │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 3, 3, 96)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 3, 3, 256)      │     2,973,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model2.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
y_train=np.array(y)

# %%
y_train.shape
# Out:
# (32197,)

# %%
history = model2.fit(x_train_scaled, y_train, validation_split=0.25, epochs=25)
# Out:
# Epoch 1/25
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.3734 - loss: 1.5035 - val_accuracy: 0.0000e+00 - val_loss: 7.4866
# Epoch 2/25
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5196 - loss: 1.1835 - val_accuracy: 0.0834 - val_loss: 9.3201
# Epoch 3/25
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5800 - loss: 1.0319 - val_accuracy: 0.0064 - val_loss: 5.0433
# Epoch 4/25
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6407 - loss: 0.8900 - val_accuracy: 5.8497e-04 - val_loss: 5.1102
# Epoch 5/25
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6716 - loss: 0.8102 - val_accuracy: 0.0023 - val_loss: 7.9536
# Epoch 6/25
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7170 - loss: 0.7159 - val_accuracy: 0.0067 - val_loss: 6.5388
# Epoch 7/25
# 642/642 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7655 - loss: 0.6038 - val_accuracy: 0.0000e+00 - val_loss: 7.6823
# Epoch 8/25
# ...

# %%
y1_test=np.array(y_test)

# %%
loss, accuracy = model2.evaluate(x_test_scaled, y1_test)
print('Test Accuracy =', accuracy)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2709 - loss: 4.2240
# Test Accuracy = 0.24993033707141876

# %%
y_pred_probs1 = model2.predict(x_test_scaled)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
y_pred2 = np.argmax(y_pred_probs1, axis=1)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt
import numpy as np

# Assuming y_pred contains predicted labels and y1_test contains true labels
emotion_labels = ["Angry", "Disgusted", "Fearful", "Happy", "Neutral", "Sad", "Surprised"]

# Calculate confusion matrix
cm = confusion_matrix(y1_test, y_pred2, normalize='true')  # Normalized confusion matrix

# Display the confusion matrix with emotion labels
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=emotion_labels)
disp.plot(cmap=plt.cm.Blues)

plt.title("Normalized Confusion Matrix with Emotion Labels")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# Calculate precision, recall, and F1-score for each class
report = classification_report(y1_test, y_pred2, target_names=emotion_labels, digits=3)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        Angry      0.164     0.050     0.077       958
#    Disgusted      0.000     0.000     0.000       111
#      Fearful      0.172     0.386     0.238      1024
#        Happy      0.299     0.739     0.426      1774
#      Neutral      0.192     0.032     0.056      1233
#          Sad      0.000     0.000     0.000      1247
#    Surprised      0.000     0.000     0.000       831
#
#     accuracy                          0.250      7178
#    macro avg      0.118     0.172     0.114      7178
# weighted avg      0.153     0.250     0.159      7178
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
model3 = tf.keras.models.Sequential([
    # First Block of Conv Layers
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 1), padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    tf.keras.layers.Dropout(0.25),

    # Second Block of Conv Layers
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    tf.keras.layers.Dropout(0.25),

    # Third Block of Conv Layers
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    tf.keras.layers.Dropout(0.25),

    # Fourth Block of Conv Layers
    tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    tf.keras.layers.Dropout(0.25),

    # Fifth Block of Conv Layers
    tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    tf.keras.layers.Dropout(0.25),

    # Flatten Layer
    tf.keras.layers.Flatten(),

    # Fully Connected Layers
    tf.keras.layers.Dense(4096, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(4096, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1024, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.5),

    # Output Layer
    tf.keras.layers.Dense(num_classes, activation='softmax')
])
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model3.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_29 (Conv2D)              │ (None, 32, 32, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_30 (Conv2D)              │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ...

# %%
model3.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

# %%
# Using validation_split with model.fit
history = model3.fit(
    x_train_scaled, y_train,  # Use only training data
    batch_size=64,
    epochs=25,
    validation_split=0.2,  # 20% of the training data will be used for validation
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/25
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 51s 101ms/step - accuracy: 0.2522 - loss: 66.1138 - val_accuracy: 0.0000e+00 - val_loss: 61.4591 - learning_rate: 0.0100
# Epoch 2/25
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.3059 - loss: 57.6044 - val_accuracy: 0.0000e+00 - val_loss: 54.5883 - learning_rate: 0.0100
# Epoch 3/25
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.3269 - loss: 50.4012 - val_accuracy: 0.0000e+00 - val_loss: 48.2448 - learning_rate: 0.0100
# Epoch 4/25
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.3368 - loss: 44.1355 - val_accuracy: 0.0000e+00 - val_loss: 42.8409 - learning_rate: 0.0100
# Epoch 5/25
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.3577 - loss: 38.6583 - val_accuracy: 0.0000e+00 - val_loss: 38.2843 - learning_rate: 0.0100
# Epoch 6/25
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.4081 - loss: 33.8347 - val_accuracy: 0.0000e+00 - val_loss: 34.5684 - learning_rate: 0.0100
# Epoch 7/25
# ...

# %%
loss, accuracy = model3.evaluate(x_test_scaled, y1_test)
print('Test Accuracy =', accuracy)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.5643 - loss: 3.7564
# Test Accuracy = 0.41237112879753113

# %%
y_pred_probs = model3.predict(x_test_scaled)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step

# %%
y_pred3 = np.argmax(y_pred_probs, axis=1)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt
import numpy as np

# Assuming y_pred contains predicted labels and y1_test contains true labels
emotion_labels = ["Angry", "Disgusted", "Fearful", "Happy", "Neutral", "Sad", "Surprised"]

# Calculate confusion matrix
cm = confusion_matrix(y1_test, y_pred3, normalize='true')  # Normalized confusion matrix

# Display the confusion matrix with emotion labels
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=emotion_labels)
print(cm)
disp.plot(cmap=plt.cm.Blues)

plt.title("Normalized Confusion Matrix with Emotion Labels")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# Calculate precision, recall, and F1-score for each class
report = classification_report(y1_test, y_pred3, target_names=emotion_labels, digits=3)
print("Classification Report:\n", report)
# Out:
# [[0.50835073 0.00939457 0.25052192 0.12421712 0.10751566 0.
#   0.        ]
#  [0.25225225 0.59459459 0.10810811 0.04504505 0.         0.
#   0.        ]
#  [0.13867188 0.00683594 0.64257812 0.09863281 0.11328125 0.
#   0.        ]
#  [0.03833145 0.         0.07666291 0.84723788 0.03776776 0.
#   0.        ]
#  [0.19708029 0.00486618 0.3730738  0.22546634 0.19951338 0.
#   0.        ]
#  [0.23656776 0.00561347 0.35284683 0.17481957 0.23015237 0.
#   0.        ]
#  [0.06979543 0.00481348 0.76413959 0.10950662 0.05174489 0.
#   0.        ]]
# Classification Report:
#                precision    recall  f1-score   support
#
#        Angry      0.369     0.508     0.427       958
#    Disgusted      0.667     0.595     0.629       111
#      Fearful      0.255     0.643     0.365      1024
#        Happy      0.649     0.847     0.735      1774
#      Neutral      0.285     0.200     0.235      1233
#          Sad      0.000     0.000     0.000      1247
# ...
